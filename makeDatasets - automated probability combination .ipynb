# %%
# Not 100% finished yet

from __future__ import division
import pandas as pd
import numpy as np
#from sklearn.preprocessing import LabelEncoder

LABEL = 'returnQuantity'

def extract_non_probabilities_features(df):

	# Deletions
	# print "\t\t WARNING: Script ini hapus: deviceID, voucherID"
	# del df['deviceID']
	# del df['voucherID']

	# Total price for an order
	order_total_dict = df[['orderID', 'price']].groupby('orderID').sum()['price'].to_dict()
	df['order_total'] = df.orderID.apply(order_total_dict.get).astype(np.float32)
	del order_total_dict

	# Average budget of the customer
	customer_budget_dict = df[['customerID', 'order_total']].groupby('customerID').mean()['order_total'].to_dict()
	df['customer_budget'] = df.customerID.apply(customer_budget_dict.get).astype(np.float32)
	del customer_budget_dict

	# Customer expense ratio	
	total_spent_dict = df[['customerID', 'order_total']].groupby('customerID').sum()['order_total'].to_dict()
	df['total_spent'] = df.customerID.apply(total_spent_dict.get).astype(np.float32)
	del total_spent_dict

	df['expense_ratio'] = (df['customer_budget'] / df['total_spent']).astype(np.float16)

	# Total_spent dihapus. Kalau nggak mau dihapus, comment aja
	del df['total_spent']


	# 2 baris ini untuk mencegah `quantity = 0`, para infaqers
	temp_quantity = df.quantity.copy()
	temp_quantity[temp_quantity==0] = 1

	# unit_price = price / quantity. by @amirahff
	df['unit_price'] = (df.price/temp_quantity).astype(np.float32)
	del temp_quantity

	# Median unit price, the usual unit price
	median_unit_price_dict = df[['articleID', 'unit_price']].groupby('articleID').median().unit_price.to_dict()
	df['median_unit_price']=df.articleID.apply(median_unit_price_dict.get).astype(np.float32)
	del median_unit_price_dict

	df['price_diff'] = (df['unit_price']-df.median_unit_price).astype(np.float32)

	# Price after discount = order_total - voucherAmount
	df['after_voucher'] = df.order_total - df.voucherAmount

	# Orders (as in rank)
	df['order_order']  = df[['customerID', 'orderID']].groupby(['customerID']).cumcount() + 1
	df['choice_order'] = df[['orderID', 'articleID']].groupby(['orderID']).cumcount() + 1
	
	# Reduce float/int precision
	float_64_columns = df.loc[:, df.dtypes == np.float64].columns
	for col in float_64_columns:
		df[col] = df[col].astype(np.float32)

	int_64_columns = df.loc[:, df.dtypes == np.int64].columns
	for col in int_64_columns:
		df[col] = df[col].astype(np.int32)

	return df
        
def extract_cumprob(df):

	def append_return_cumprob(df, input_column):
		target_column_name = input_column + '_cumprob'

		df_temp = df[[input_column, 'returnQuantity','quantity']]
		df_return_probability = df_temp.groupby(input_column)['returnQuantity','quantity'].cumsum()

		df_return_probability[ target_column_name ]  = df_return_probability.returnQuantity / df_return_probability.quantity
		df[ target_column_name ] = df_return_probability[ target_column_name ].replace(np.NaN, 0.5).replace(np.inf, 0.5).apply(lambda x: 1 if x > 1 else x)
		
		del df_return_probability
        
	def append_return_cumprob_from_multiple_column(df, input_columns):
		column_prefix = ''
		for i in range(0,len(input_columns)):
			column_prefix = column_prefix + input_columns[i][0]+ input_columns[i][1]
		target_column_name = column_prefix + '_prob' 

		df_temp = df[ input_columns + ['returnQuantity','quantity'] ]

		df_return_probability = df_temp.groupby(input_columns).cumsum()
		df_return_probability[ target_column_name ]  = df_return_probability.returnQuantity / df_return_probability.quantity

		df[ target_column_name ] = df_return_probability[ target_column_name ].replace(np.NaN, 0.5).replace(np.inf, 0.5).apply(lambda x: 1 if x > 1 else x)

		del df_return_probability

	oneFeature = ['articleID','colorCode','sizeCode','productGroup','voucherID','customerID','deviceID','paymentMethod']
	#cumprob for one feature
	for x in oneFeature:
		append_return_cumprob(df, x)

	#cumprob for two features
	for i in range(0,len(oneFeature)):
		for j in range(i+1,len(oneFeature)):
			komb = [oneFeature[i], oneFeature[j]]
			append_return_cumprob_from_multiple_column(df, komb)
    
	#cumprob for three features
	for i in range(0,len(oneFeature)):
		for j in range(i+1,len(oneFeature)):
			for k in range(j+1,len(oneFeature)):
				komb = [oneFeature[i], oneFeature[j], oneFeature[k]]
				append_return_cumprob_from_multiple_column(df, komb)
                        
	del oneFeature
    
	return df

def append_cumprob_to_tests_df(train_df, tests_df):

	def append_return_prob(column, train_df, tests_df):
		df2 = train_df[[column,'returnQuantity','quantity']]
		df_return_probability = df2.groupby(column).sum()
		df_return_probability[ column + '_prob' ]  = df_return_probability.returnQuantity / df_return_probability.quantity
		return_prob_dict = df_return_probability[ column + '_prob' ].to_dict()
		del df_return_probability
		tests_df[ column + '_prob' ] = tests_df[column].apply(return_prob_dict.get).replace(np.NaN, 0.5).replace(np.inf, 0.5).apply(lambda x: 1 if x > 1 else x)
		del return_prob_dict
        
	def append_return_prob_from_multiple_column(input_columns, input_df, target_df):
		column_prefix = ''
		for i in range(0,len(input_columns)):
			column_prefix = column_prefix + input_columns[i][0] + input_columns[i][1]
		target_column_name = column_prefix + '_prob' 

		print "\t\t append_return_prob_from_two_column:", input_columns, ' -> ',target_column_name

		df_temp = input_df[ input_columns + ['returnQuantity','quantity'] ]

		df_return_probability = df_temp.groupby(input_columns).sum()
		df_return_probability[ target_column_name ]  = df_return_probability.returnQuantity / df_return_probability.quantity

		prob_dict  = df_return_probability[target_column_name].to_dict()
		target_df[target_column_name] = target_df[input_columns].apply(tuple, axis=1).apply(prob_dict.get).replace(np.nan, 0.5).replace(np.inf, 0.5)

		del df_return_probability

	oneFeature = ['articleID','colorCode','sizeCode','productGroup','voucherID','customerID','deviceID','paymentMethod']
	#prob for one feature to test
	for x in oneFeature:
		append_return_prob(x, train_df, tests_df)

	#cumprob for two features to test
	for i in range(0,len(oneFeature)):
		for j in range(i+1,len(oneFeature)):
			komb = [oneFeature[i], oneFeature[j]]
			append_return_prob_from_multiple_column(komb, input_df=train_df, target_df=tests_df)
    
	#cumprob for three features to test
	for i in range(0,len(oneFeature)):
		for j in range(i+1,len(oneFeature)):
			for k in range(j+1,len(oneFeature)):
				komb = [oneFeature[i], oneFeature[j], oneFeature[k]]
				append_return_prob_from_multiple_column(komb, input_df=train_df, target_df=tests_df)
                        
	del oneFeature
    
	return tests_df

def main():
	from datetime import datetime
	time = lambda: datetime.now().time()

	LABEL = 'returnQuantity'

	print 'ETA: ~18 minutes'

	#
	print time(), 'Loading data.'
	train_df = pd.read_csv('orders_train.txt', sep=';')
	tests_df = pd.read_csv('orders_class.txt', sep=';')
	df = pd.concat([train_df, tests_df], axis=0, ignore_index=True)

	# split at the end of train_df index
	split = train_df.shape[0]

	# delete train_df & tests_df
	#del train_df
	#del tests_df

	#
	print time(), 'Extracting non-probabilities features.'
	df = extract_non_probabilities_features(df)

	#
	print time(), 'Splitting dataframes.'

	train_df = df[:split]
	tests_df = df[split:].drop(LABEL, axis=1)

	#
	print time(), 'Extracting cumprob to train_df. (SLOW)'
	train_df = extract_cumprob(train_df)

	#
	print time(), 'Extracting prob to tests_df. (SLOW)'
	tests_df = append_cumprob_to_tests_df(train_df, tests_df)

	#
	print time(), 'Writing to CSVs. ETA 7 minutes'

	train_df.to_csv('train_gue5.csv', index=False)
	tests_df.to_csv('tests_gue5.csv', index=False)

	#
	print time(), 'Done'

if __name__ == "__main__":
	main()
# Out:
# ETA: ~18 minutes
# 02:08:34.326000 Loading data.
# 02:08:47.558000 Extracting non-probabilities features.
# 02:09:33.983000 Splitting dataframes.
# 02:09:34.290000 Extracting cumprob to train_df. (SLOW)
# C:\Users\LENOVO\Anaconda2\lib\site-packages\ipykernel\__main__.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\LENOVO\Anaconda2\lib\site-packages\ipykernel\__main__.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 02:40:22.089000 Extracting prob to tests_df. (SLOW)
# 		 append_return_prob_from_two_column: ['articleID', 'colorCode']  ->  arco_prob
# 		 append_return_prob_from_two_column: ['articleID', 'sizeCode']  ->  arsi_prob
# 		 append_return_prob_from_two_column: ['articleID', 'productGroup']  ->  arpr_prob
# 		 append_return_prob_from_two_column: ['articleID', 'voucherID']  ->  arvo_prob
# 		 append_return_prob_from_two_column: ['articleID', 'customerID']  ->  arcu_prob
# 		 append_return_prob_from_two_column: ['articleID', 'deviceID']  ->  arde_prob
# 		 append_return_prob_from_two_column: ['articleID', 'paymentMethod']  ->  arpa_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'sizeCode']  ->  cosi_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'productGroup']  ->  copr_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'voucherID']  ->  covo_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'customerID']  ->  cocu_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'deviceID']  ->  code_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'paymentMethod']  ->  copa_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'productGroup']  ->  sipr_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'voucherID']  ->  sivo_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'customerID']  ->  sicu_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'deviceID']  ->  side_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'paymentMethod']  ->  sipa_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'voucherID']  ->  prvo_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'customerID']  ->  prcu_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'deviceID']  ->  prde_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'paymentMethod']  ->  prpa_prob
# 		 append_return_prob_from_two_column: ['voucherID', 'customerID']  ->  vocu_prob
# 		 append_return_prob_from_two_column: ['voucherID', 'deviceID']  ->  vode_prob
# 		 append_return_prob_from_two_column: ['voucherID', 'paymentMethod']  ->  vopa_prob
# 		 append_return_prob_from_two_column: ['customerID', 'deviceID']  ->  cude_prob
# 		 append_return_prob_from_two_column: ['customerID', 'paymentMethod']  ->  cupa_prob
# 		 append_return_prob_from_two_column: ['deviceID', 'paymentMethod']  ->  depa_prob
# 		 append_return_prob_from_two_column: ['articleID', 'colorCode', 'sizeCode']  ->  arcosi_prob
# 		 append_return_prob_from_two_column: ['articleID', 'colorCode', 'productGroup']  ->  arcopr_prob
# 		 append_return_prob_from_two_column: ['articleID', 'colorCode', 'voucherID']  ->  arcovo_prob
# 		 append_return_prob_from_two_column: ['articleID', 'colorCode', 'customerID']  ->  arcocu_prob
# 		 append_return_prob_from_two_column: ['articleID', 'colorCode', 'deviceID']  ->  arcode_prob
# 		 append_return_prob_from_two_column: ['articleID', 'colorCode', 'paymentMethod']  ->  arcopa_prob
# 		 append_return_prob_from_two_column: ['articleID', 'sizeCode', 'productGroup']  ->  arsipr_prob
# 		 append_return_prob_from_two_column: ['articleID', 'sizeCode', 'voucherID']  ->  arsivo_prob
# 		 append_return_prob_from_two_column: ['articleID', 'sizeCode', 'customerID']  ->  arsicu_prob
# 		 append_return_prob_from_two_column: ['articleID', 'sizeCode', 'deviceID']  ->  arside_prob
# 		 append_return_prob_from_two_column: ['articleID', 'sizeCode', 'paymentMethod']  ->  arsipa_prob
# 		 append_return_prob_from_two_column: ['articleID', 'productGroup', 'voucherID']  ->  arprvo_prob
# 		 append_return_prob_from_two_column: ['articleID', 'productGroup', 'customerID']  ->  arprcu_prob
# 		 append_return_prob_from_two_column: ['articleID', 'productGroup', 'deviceID']  ->  arprde_prob
# 		 append_return_prob_from_two_column: ['articleID', 'productGroup', 'paymentMethod']  ->  arprpa_prob
# 		 append_return_prob_from_two_column: ['articleID', 'voucherID', 'customerID']  ->  arvocu_prob
# 		 append_return_prob_from_two_column: ['articleID', 'voucherID', 'deviceID']  ->  arvode_prob
# 		 append_return_prob_from_two_column: ['articleID', 'voucherID', 'paymentMethod']  ->  arvopa_prob
# 		 append_return_prob_from_two_column: ['articleID', 'customerID', 'deviceID']  ->  arcude_prob
# 		 append_return_prob_from_two_column: ['articleID', 'customerID', 'paymentMethod']  ->  arcupa_prob
# 		 append_return_prob_from_two_column: ['articleID', 'deviceID', 'paymentMethod']  ->  ardepa_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'sizeCode', 'productGroup']  ->  cosipr_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'sizeCode', 'voucherID']  ->  cosivo_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'sizeCode', 'customerID']  ->  cosicu_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'sizeCode', 'deviceID']  ->  coside_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'sizeCode', 'paymentMethod']  ->  cosipa_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'productGroup', 'voucherID']  ->  coprvo_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'productGroup', 'customerID']  ->  coprcu_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'productGroup', 'deviceID']  ->  coprde_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'productGroup', 'paymentMethod']  ->  coprpa_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'voucherID', 'customerID']  ->  covocu_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'voucherID', 'deviceID']  ->  covode_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'voucherID', 'paymentMethod']  ->  covopa_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'customerID', 'deviceID']  ->  cocude_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'customerID', 'paymentMethod']  ->  cocupa_prob
# 		 append_return_prob_from_two_column: ['colorCode', 'deviceID', 'paymentMethod']  ->  codepa_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'productGroup', 'voucherID']  ->  siprvo_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'productGroup', 'customerID']  ->  siprcu_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'productGroup', 'deviceID']  ->  siprde_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'productGroup', 'paymentMethod']  ->  siprpa_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'voucherID', 'customerID']  ->  sivocu_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'voucherID', 'deviceID']  ->  sivode_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'voucherID', 'paymentMethod']  ->  sivopa_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'customerID', 'deviceID']  ->  sicude_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'customerID', 'paymentMethod']  ->  sicupa_prob
# 		 append_return_prob_from_two_column: ['sizeCode', 'deviceID', 'paymentMethod']  ->  sidepa_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'voucherID', 'customerID']  ->  prvocu_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'voucherID', 'deviceID']  ->  prvode_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'voucherID', 'paymentMethod']  ->  prvopa_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'customerID', 'deviceID']  ->  prcude_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'customerID', 'paymentMethod']  ->  prcupa_prob
# 		 append_return_prob_from_two_column: ['productGroup', 'deviceID', 'paymentMethod']  ->  prdepa_prob
# 		 append_return_prob_from_two_column: ['voucherID', 'customerID', 'deviceID']  ->  vocude_prob
# 		 append_return_prob_from_two_column: ['voucherID', 'customerID', 'paymentMethod']  ->  vocupa_prob
# 		 append_return_prob_from_two_column: ['voucherID', 'deviceID', 'paymentMethod']  ->  vodepa_prob
# 		 append_return_prob_from_two_column: ['customerID', 'deviceID', 'paymentMethod']  ->  cudepa_prob
# 03:00:39.996000 Writing to CSVs. ETA 7 minutes
# 03:21:35.668000 Done
